# %%
import numpy as np
import matplotlib.pyplot as plt
#import muram as mio
from astropy.io import fits
import pyflct
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
from matplotlib import font_manager
import matplotlib as mpl
font_path = '/home/mistflow/.fonts/Ubuntu.ttf'  # Your font path goes here
#font_path = '/usr/share/fonts/opentype/urw-base35/NimbusRoman-Italic.otf'
font_manager.fontManager.addfont(font_path)
prop = font_manager.FontProperties(fname=font_path)
mpl.rcParams["font.size"] = 14
mpl.rcParams['axes.formatter.useoffset'] = False
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = prop.get_name()
#plt.rc('text', usetex=True)
#plt.rc('axes', unicode_minus=False)
#width, height = plt.rcParams.get('figure.figsize')

# %%
from scipy.stats import pearsonr
from scipy.ndimage import gaussian_filter
from scipy.stats import linregress

# %%
import illuminated_finite_slab as ils

# %%
tau_max = 1e3

ND__1 = 21
epsilon__1 = np.ones(ND__1) * 5e-3
B__1 = np.ones(ND__1) * 5.0

# %%
ND__2 = 51
epsilon__2 = np.ones(ND__2) * 5e-3
B__2 = np.ones(ND__2) * 5.0

# %%
ND__3 = 81
epsilon__3 = np.ones(ND__3) * 5e-3
B__3 = np.ones(ND__3) * 5.0

# %%
ND__4 = 101
epsilon__4 = np.ones(ND__4) * 5e-3
B__4 = np.ones(ND__4) * 5.0

# %%
ND__5 = 121
epsilon__5 = np.ones(ND__5) * 5e-3
B__5 = np.ones(ND__5) * 5.0

# %%
ND__6 = 151
epsilon__6 = np.ones(ND__6) * 5e-3
B__6 = np.ones(ND__6) * 5.0

# %%
ND__7 = 181
epsilon__7 = np.ones(ND__7) * 5e-3
B__7 = np.ones(ND__7) * 5.0

# %%
ND__8 = 201
epsilon__8 = np.ones(ND__8) * 5e-3
B__8 = np.ones(ND__8) * 5.0

# %%
Slab__1 = ils.Slab(ND__1, tau_max, epsilon__1, B__1, H=10e6)
Slab__1.calculate_J_scat()
Slab__1.solve_source_function_ALO(max_iter=200, tol=1e-6)
max_change__1 = Slab__1.rel_err
t_change__1 = Slab__1.true_err
S__1 = Slab__1.S
# Out:
# Converged after 18 iterations.

# %%
Slab__2 = ils.Slab(ND__2, tau_max, epsilon__2, B__2, H=10e6)
Slab__2.calculate_J_scat()
Slab__2.solve_source_function_ALO(max_iter=200, tol=1e-6)
max_change__2 = Slab__2.rel_err
t_change__2 = Slab__2.true_err
S__2 = Slab__2.S
# Out:
# Converged after 57 iterations.

# %%
Slab__3 = ils.Slab(ND__3, tau_max, epsilon__3, B__3, H=10e6)
Slab__3.calculate_J_scat()
Slab__3.solve_source_function_ALO(max_iter=200, tol=1e-6)
max_change__3 = Slab__3.rel_err
t_change__3 = Slab__3.true_err
S__3 = Slab__3.S
# Out:
# Converged after 86 iterations.

# %%
Slab__4 = ils.Slab(ND__4, tau_max, epsilon__4, B__4, H=10e6)
Slab__4.calculate_J_scat()
Slab__4.solve_source_function_ALO(max_iter=200, tol=1e-6)
max_change__4 = Slab__4.rel_err
t_change__4 = Slab__4.true_err
S__4 = Slab__4.S
# Out:
# Converged after 104 iterations.

# %%
Slab__5 = ils.Slab(ND__5, tau_max, epsilon__5, B__5, H=10e6)
Slab__5.calculate_J_scat()
Slab__5.solve_source_function_ALO(max_iter=200, tol=1e-6)
max_change__5 = Slab__5.rel_err
t_change__5 = Slab__5.true_err
S__5 = Slab__5.S
# Out:
# Converged after 120 iterations.

# %%
Slab__6 = ils.Slab(ND__6, tau_max, epsilon__6, B__6, H=10e6)
Slab__6.calculate_J_scat()
Slab__6.solve_source_function_ALO(max_iter=200, tol=1e-6)
max_change__6 = Slab__6.rel_err
t_change__6 = Slab__6.true_err
S__6 = Slab__6.S
# Out:
# Converged after 142 iterations.

# %%
Slab__7 = ils.Slab(ND__7, tau_max, epsilon__7, B__7, H=10e6)
Slab__7.calculate_J_scat()
Slab__7.solve_source_function_ALO(max_iter=200, tol=1e-6)
max_change__7 = Slab__7.rel_err
t_change__7 = Slab__7.true_err
S__7 = Slab__7.S
# Out:
# Converged after 162 iterations.

# %%
Slab__8 = ils.Slab(ND__8, tau_max, epsilon__8, B__8, H=10e6)
Slab__8.calculate_J_scat()
Slab__8.solve_source_function_ALO(max_iter=200, tol=1e-6)
max_change__8 = Slab__8.rel_err
t_change__8 = Slab__8.true_err
S__8 = Slab__8.S
# Out:
# Converged after 174 iterations.

# %%
plt.figure(figsize=(8,6))
plt.semilogy(np.log10(Slab__1.tau),S__1, linestyle = "-", linewidth = 1.0, color = "orange", label=f"ND={ND__1}")
plt.semilogy(np.log10(Slab__2.tau),S__2, linestyle = "-", linewidth = 0.5, color = "red", label=f"ND={ND__2}")
plt.semilogy(np.log10(Slab__3.tau),S__3, linestyle = "-", linewidth = 0.5, color = "green", label=f"ND={ND__3}")
plt.semilogy(np.log10(Slab__4.tau),S__4, linestyle = "-", linewidth = 0.5, color = "blue", label=f"ND={ND__4}")
plt.semilogy(np.log10(Slab__5.tau),S__5, linestyle = "-", linewidth = 0.5, color = "black", label=f"ND={ND__5}")
plt.semilogy(np.log10(Slab__6.tau),S__6, linestyle = "-", linewidth = 0.5, color = "maroon", label=f"ND={ND__6}")
plt.semilogy(np.log10(Slab__7.tau),S__7, linestyle = "-", linewidth = 0.5, color = "navy", label=f"ND={ND__7}")
plt.semilogy(np.log10(Slab__8.tau),S__8, linestyle = "-", linewidth = 0.5, color = "purple", label=f"ND={ND__8}")
#plt.semilogy(np.log10(slab.tau),slab.J_scat, label="J_scat")
#plt.semilogy(np.log10(slab.tau),S_direct, linestyle = "--", color = "green", alpha = 1.0, label="S Direct")
#plt.plot(np.log10(slab.tau),S_direct, linestyle = "-.", color = "blue", alpha = 0.5, label="S, ALO solved")
plt.xlabel("log10(Tau)")
plt.ylabel("Source Function ")
plt.title("Source Function vs Optical Depth")
#plt.ylim([3.4e-1,4.1e-1])
plt.legend()
plt.grid()
plt.tight_layout()
#plt.savefig(f"source_function_jscat_ND_{ND}_taum_{tau_max}_eps_{epsilon[0]}_B_{B[0]}.png",bbox_inches='tight')
#plt.show()

# %%
plt.figure(figsize=(17,8))
plt.subplot(121)
plt.semilogy(max_change__1, linestyle = "-", linewidth = 1.0, color = "orange", label=f"ND={ND__1}")
plt.semilogy(max_change__2, linestyle = "-", linewidth = 0.5, color = "red", label=f"ND={ND__2}")
plt.semilogy(max_change__3, linestyle = "-", linewidth = 0.5, color = "green", label=f"ND={ND__3}")
plt.semilogy(max_change__4, linestyle = "-", linewidth = 0.5, color = "blue", label=f"ND={ND__4}")
plt.semilogy(max_change__5, linestyle = "-", linewidth = 0.5, color = "black", label=f"ND={ND__5}")
plt.semilogy(max_change__6, linestyle = "-", linewidth = 0.5, color = "maroon", label=f"ND={ND__6}")
plt.semilogy(max_change__7, linestyle = "-", linewidth = 0.5, color = "navy", label=f"ND={ND__7}")
plt.semilogy(max_change__8, linestyle = "-", linewidth = 0.5, color = "purple", label=f"ND={ND__8}")
#plt.semilogy(np.log10(slab.tau),slab.J_scat, label="J_scat")
#plt.semilogy(np.log10(slab.tau),S_direct, linestyle = "--", color = "green", alpha = 1.0, label="S Direct")
#plt.plot(np.log10(slab.tau),S_direct, linestyle = "-.", color = "blue", alpha = 0.5, label="S, ALO solved")
plt.xlabel("Iteration num")
plt.ylabel("Relative error")
plt.title("Rel Err of Source Function vs Optical Depth")
#plt.ylim(0, 0.5)
#plt.xlim(0, 25)
plt.legend()
plt.grid()
plt.subplot(122)
plt.semilogy(t_change__1, linestyle = "-", linewidth = 1.0, color = "orange", label=f"ND={ND__1}")
plt.semilogy(t_change__2, linestyle = "-", linewidth = 0.5, color = "red", label=f"ND={ND__2}")
plt.semilogy(t_change__3, linestyle = "-", linewidth = 0.5, color = "green", label=f"ND={ND__3}")
plt.semilogy(t_change__4, linestyle = "-", linewidth = 0.5, color = "blue", label=f"ND={ND__4}")
plt.semilogy(t_change__5, linestyle = "-", linewidth = 0.5, color = "black", label=f"ND={ND__5}")
plt.semilogy(t_change__6, linestyle = "-", linewidth = 0.5, color = "maroon", label=f"ND={ND__6}")
plt.semilogy(t_change__7, linestyle = "-", linewidth = 0.5, color = "navy", label=f"ND={ND__7}")
plt.semilogy(t_change__8, linestyle = "-", linewidth = 0.5, color = "purple", label=f"ND={ND__8}")
#plt.semilogy(np.log10(slab.tau),slab.J_scat, label="J_scat")
#plt.semilogy(np.log10(slab.tau),S_direct, linestyle = "--", color = "green", alpha = 1.0, label="S Direct")
#plt.plot(np.log10(slab.tau),S_direct, linestyle = "-.", color = "blue", alpha = 0.5, label="S, ALO solved")
plt.xlabel("Iteration num")
plt.ylabel("True error")
plt.title("True Err of Source Function vs Optical Depth")
#plt.ylim(0, 0.5)
#plt.xlim(0, 25)
plt.legend()
plt.grid()
plt.tight_layout()
